# %% [markdown]
# # Addressing labeling annotation errors in COCO-2017 through model output inspection and mistakenness

# %% [markdown]
# # COCO-2017 Book Label Problems
#
# The COCO-2017 validation set contains numerous incorrect "book" annotations. Objects like shelves, desks, album covers, and kitchen equipment are mislabeled as books.
#
# ## Root causes
#
# `Human Annotation Errors`: Crowdworkers made mistakes when annotating objects, often confusing rectangular items with actual books or labeling whole stacks or shelves of books as 'book'.
#
# `Vague Guidelines`: The original annotation instructions lacked precise guidelines about what constitutes a book versus other flat, rectangular objects.
#
# `Quality Control Gaps`: Many errors passed through the review process, particularly for less distinctive object categories.
#
# These mislabeled annotations create systematic bias in the dataset. Models trained on this data learn incorrect associations, leading to reduced performance on detection tasks.
#
# ![](https://raw.githubusercontent.com/andandandand/practical-computer-vision/refs/heads/main/images/books_ground_truth.png)
#
#
# ## Using models to relabel
#
# We can use automated verification methods to identify and correct suspicious annotations based on object shape, context, and visual features. FiftyOne's [mistakenness](https://docs.voxel51.com/tutorials/detection_mistakes.html) metric provides a great starting point.
#
# While relabeling we can apply techniques that handle label noise better, such as confidence-based filtering or using the output of one or various models to produce soft labels.
#
# Clean datasets like [COCO-ReM](https://github.com/kdexd/coco-rem)have been created using ensembles of models and active learning to produce higher quality labeling.
#
# FiftyOne's [verified auto-labeling](https://arxiv.org/abs/2506.02359) addresses many of these issues in labeling for object detection, producing cleaned-up versions of the COCO-2017 dataset through model ensembling.

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.brain as fob
from pathlib import Path

# %% [markdown]
# ## Import dataset

# %%
parent_path = Path('/Users/antonio/Documents/Projects/GettingStartedWithFiftyOne/local_run/')
dataset_dir = str(parent_path / 'data/coco-validation-books')

# %%
# The type of the dataset being imported
dataset_type = fo.types.COCODetectionDataset  
# Import the dataset
dataset = fo.Dataset.from_dir(
    dataset_dir=dataset_dir,
    dataset_type=dataset_type,
    label_field="ground_truth",
)
# Out:
#  100% |█████████████████| 230/230 [446.4ms elapsed, 0s remaining, 516.1 samples/s]

# %%
dataset.compute_metadata()

# %%
session = fo.launch_app(dataset, auto=False)
print(session.url)
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.
# http://localhost:5151/

# %%
faster_rcnn_model = foz.load_zoo_model("faster-rcnn-resnet50-fpn-coco-torch")

dataset.apply_model(faster_rcnn_model, 
                    label_field="faster_rcnn_predictions", 
                    batch_size=32)
# Out:
# Model does not support batching
#  100% |█████████████████| 230/230 [2.9m elapsed, 0s remaining, 1.2 samples/s]

# %%
sample = dataset.first()
sample
# Out:
# <Sample: {
#     'id': '685223562610176497b52104',
#     'media_type': 'image',
#     'filepath': '/Users/antonio/Documents/Projects/GettingStartedWithFiftyOne/local_run/data/coco-validation-books/data/000000000139.jpg',
#     'tags': [],
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 640,
#         'height': 426,
#         'num_channels': None,
#     }>,
#     'created_at': datetime.datetime(2025, 6, 18, 2, 24, 22, 502000),
#     'last_modified_at': datetime.datetime(2025, 6, 18, 2, 28, 39, 423000),
#     'detections': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '685223562610176497b52100',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'book',
#                 'bounding_box': [
#                     0.944953125,
#                     0.7180516431924883,
#                     0.02240625,
#                     0.10730046948356808,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#                 'supercategory': 'indoor',
#             }>,
#             <Detection: {
#                 'id': '685223562610176497b52101',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'book',
#                 'bounding_box': [
#                     0.9581875,
#                     0.7235680751173709,
#                     0.020125,
#                     0.10901408450704225,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#                 'supercategory': 'indoor',
#             }>,
#         ],
#     }>,
#     'faster_rcnn_predictions': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '685224572610176497b52afa',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.45533522963523865,
#                     0.5087209939956665,
#                     0.09598994255065918,
#                     0.23675429821014404,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9965628981590271,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52afb',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.5799723863601685,
#                     0.5081489086151123,
#                     0.08511991798877716,
#                     0.2353363037109375,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9920255541801453,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52afc',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'tv',
#                 'bounding_box': [
#                     0.010052619501948357,
#                     0.3953245282173157,
#                     0.2317042350769043,
#                     0.22625993192195892,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9919740557670593,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52afd',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'potted plant',
#                 'bounding_box': [
#                     0.36077770590782166,
#                     0.4102816879749298,
#                     0.05604586750268936,
#                     0.0916808545589447,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9845151901245117,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52afe',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'person',
#                 'bounding_box': [
#                     0.6644569635391235,
#                     0.3752240240573883,
#                     0.0618649497628212,
#                     0.3278054893016815,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9838051199913025,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52aff',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'clock',
#                 'bounding_box': [
#                     0.7013137340545654,
#                     0.28434810042381287,
#                     0.018732452765107155,
#                     0.050112172961235046,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9685736298561096,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b00',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.37822189927101135,
#                     0.4654529094696045,
#                     0.018076468259096146,
#                     0.033648282289505005,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9572920799255371,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b01',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.26076000928878784,
#                     0.5471932291984558,
#                     0.029953408986330032,
#                     0.07952611893415451,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9570603370666504,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b02',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'dining table',
#                 'bounding_box': [
#                     0.7278069257736206,
#                     0.8256736993789673,
#                     0.26793670654296875,
#                     0.16149185597896576,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9484843611717224,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b03',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.6444709300994873,
#                     0.5158973336219788,
#                     0.04455003887414932,
#                     0.20444580912590027,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9293389916419983,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b04',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'potted plant',
#                 'bounding_box': [
#                     0.5222700238227844,
#                     0.41796863079071045,
#                     0.05386938899755478,
#                     0.1125202476978302,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.9110987186431885,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b05',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.5485957860946655,
#                     0.48388633131980896,
#                     0.016286183148622513,
#                     0.05934877321124077,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8957406878471375,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b06',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'refrigerator',
#                 'bounding_box': [
#                     0.7685422301292419,
#                     0.3904208242893219,
#                     0.03358817100524902,
#                     0.26068538427352905,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8953020572662354,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b07',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'refrigerator',
#                 'bounding_box': [
#                     0.696803867816925,
#                     0.3928808569908142,
#                     0.10245571285486221,
#                     0.28661370277404785,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8846656084060669,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b08',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.5637909173965454,
#                     0.5030701160430908,
#                     0.020077038556337357,
#                     0.039873722940683365,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8691896200180054,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b09',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'bottle',
#                 'bounding_box': [
#                     0.8600763082504272,
#                     0.6973221302032471,
#                     0.056424520909786224,
#                     0.2419940084218979,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8436076045036316,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b0a',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.527471661567688,
#                     0.4736669361591339,
#                     0.015143871307373047,
#                     0.03222358971834183,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.8200317025184631,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b0b',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'person',
#                 'bounding_box': [
#                     0.6011907458305359,
#                     0.4049760103225708,
#                     0.026304055005311966,
#                     0.08825834095478058,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7760211229324341,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b0c',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'dining table',
#                 'bounding_box': [
#                     0.5967541933059692,
#                     0.5039587020874023,
#                     0.06459226459264755,
#                     0.013540277257561684,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.7132725715637207,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b0d',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.4910389482975006,
#                     0.45318853855133057,
#                     0.015073013491928577,
#                     0.05215522274374962,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6973950862884521,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b0e',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'dining table',
#                 'bounding_box': [
#                     0.7568752765655518,
#                     0.6866347193717957,
#                     0.24312472343444824,
#                     0.3033483028411865,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6796093583106995,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b0f',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'dining table',
#                 'bounding_box': [
#                     0.4778822958469391,
#                     0.5065560936927795,
#                     0.20294193923473358,
#                     0.23927579820156097,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6519160270690918,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b10',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'tv',
#                 'bounding_box': [
#                     0.8735021352767944,
#                     0.4935115873813629,
#                     0.12649783492088318,
#                     0.18471236526966095,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.6060631275177002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b11',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.5423203110694885,
#                     0.4834256172180176,
#                     0.022153090685606003,
#                     0.03688575699925423,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.5156952142715454,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b12',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.5476527214050293,
#                     0.5108994841575623,
#                     0.01818523369729519,
#                     0.03113280050456524,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.5042856931686401,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b13',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'handbag',
#                 'bounding_box': [
#                     0.3276311457157135,
#                     0.7025055289268494,
#                     0.0741405040025711,
#                     0.07061581313610077,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.4508216977119446,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b14',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.8592516779899597,
#                     0.7001018524169922,
#                     0.058162786066532135,
#                     0.23908337950706482,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.4479678273200989,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b15',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.6456536054611206,
#                     0.516410231590271,
#                     0.04204545170068741,
#                     0.08982168883085251,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3965969979763031,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b16',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.46612685918807983,
#                     0.5100318789482117,
#                     0.07851038128137589,
#                     0.0344063825905323,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3776937425136566,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b17',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'potted plant',
#                 'bounding_box': [
#                     0.5190995335578918,
#                     0.4355587065219879,
#                     0.03361792489886284,
#                     0.09094306081533432,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3752039968967438,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b18',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.5402144193649292,
#                     0.47782737016677856,
#                     0.014019680209457874,
#                     0.032038263976573944,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3742966651916504,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b19',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.6142340898513794,
#                     0.5063109993934631,
#                     0.07112012058496475,
#                     0.2333148717880249,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3647881746292114,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b1a',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.6214010119438171,
#                     0.4780729413032532,
#                     0.014359617605805397,
#                     0.03109719790518284,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.362979918718338,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b1b',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'dining table',
#                 'bounding_box': [
#                     0.5942888259887695,
#                     0.5082453489303589,
#                     0.07213501632213593,
#                     0.014833549037575722,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.34405893087387085,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b1c',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'vase',
#                 'bounding_box': [
#                     0.5400018692016602,
#                     0.47440800070762634,
#                     0.029165029525756836,
#                     0.06708738207817078,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3236023783683777,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '685224572610176497b52b1d',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'chair',
#                 'bounding_box': [
#                     0.5656408071517944,
#                     0.5293134450912476,
#                     0.042580269277095795,
#                     0.20047158002853394,
#                 ],
#                 'mask': None,
#                 'mask_path': None,
#                 'confidence': 0.3030160665512085,
#                 'index': None,
#             }>,
#         ],
#     }>,
# }>

# %% [markdown]
# ## Label filtering and confidence thresholding through the FiftyOne app
#
# ![](https://github.com/andandandand/practical-computer-vision/blob/main/images/full_threshold.png?raw=true)

# %% [markdown]
# ### Tag labels to remove for a new ground truth
# ![](https://github.com/andandandand/practical-computer-vision/blob/main/images/remove-labels.png?raw=true)

# %%
session.refresh()
print(session.url)
# Out:
# http://localhost:5151/

# %% [markdown]
# ## Compute mistakenness

# %% [markdown]
# `fob.compute_mistakenness()` creates the following attributes:
#
# ## Ground Truth Field
#
# * `mistakenness` (float): Likelihood that the object label is incorrect
#
# * `mistakenness_loc` (float): Likelihood that the bounding box is inaccurate
#
# * `possible_spurious` (bool): True for unmatched ground truth objects likely to be spurious annotations
#
# ## Predictions Field
#
# * `possible_missing` (bool): True for confident predictions without matching ground truth, indicating likely missing annotations
#
# # Sample-Level Fields
#
# * `mistakenness`: Maximum mistakenness value among ground truth objects in the sample
#
# * `possible_spurious`: Count of possible spurious ground truth objects in the sample
#
# * `possible_missing`: Count of possible missing ground truth objects in the sample

# %%
# Compute mistakenness of annotations in `ground_truth` field using 
# predictions from `predictions` field as point of reference
fob.compute_mistakenness(dataset, "faster_rcnn_predictions", label_field="ground_truth")
# Out:
# Evaluating detections...
#  100% |█████████████████| 230/230 [7.0s elapsed, 0s remaining, 30.1 samples/s]
# Computing mistakenness...
#  100% |█████████████████| 230/230 [1.6s elapsed, 0s remaining, 166.3 samples/s]
# Mistakenness computation complete

# %%
dataset.get_field_schema()
# Out:
# OrderedDict([('id', <fiftyone.core.fields.ObjectIdField at 0x30d69f3d0>),
#              ('filepath', <fiftyone.core.fields.StringField at 0x30d6e3190>),
#              ('tags', <fiftyone.core.fields.ListField at 0x30d6e16d0>),
#              ('metadata',
#               <fiftyone.core.fields.EmbeddedDocumentField at 0x30d69ef50>),
#              ('created_at',
#               <fiftyone.core.fields.DateTimeField at 0x30d5eb590>),
#              ('last_modified_at',
#               <fiftyone.core.fields.DateTimeField at 0x30d6e3150>),
#              ('detections',
#               <fiftyone.core.fields.EmbeddedDocumentField at 0x30d6e3dd0>),
#              ('faster_rcnn_predictions',
#               <fiftyone.core.fields.EmbeddedDocumentField at 0x30d6e0fd0>),
#              ('mistakenness', <fiftyone.core.fields.IntField at 0x346ac4790>),
#              ('possible_missing',
#               <fiftyone.core.fields.IntField at 0x30d51ffd0>),
#              ('possible_spurious',
#               <fiftyone.core.fields.IntField at 0x346acfa10>)])

# %%
session.refresh()
print(session.url)
# Out:
# http://localhost:5151/

# %% [markdown]
# ### Follow-up
#
# * [Start a CVAT session](https://docs.voxel51.com/tutorials/cvat_annotation.html) to correct the dataset's annotations.
